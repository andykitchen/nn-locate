# %%
import numpy as np
from skimage.draw import polygon

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %run load_data.py

# %%
images, labels = glob_loader(['images/background_*.jpg', 'images/shark_*.jpg'])
print labels[0], labels[51]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(images[0])
ax[1].imshow(images[51])
# Out:
# 0 1

# %%
X, Y = load_data_globs(['images/background_*.jpg', 'images/shark_*.jpg'])
print Y[0], Y[51]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(X[0])
ax[1].imshow(X[51])
# Out:
# 0 1

# %%
(X_train, Y_train), (X_validation, Y_validation) = load_data()
print Y_train[0], Y_train[51]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(X_train[0])
ax[1].imshow(X_train[51])
# Out:
# 0 1

# %%
print Y_validation[0], Yvalidation[21]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(X_validation[0])
ax[1].imshow(X_validation[21])
# Out:
# 0 1
